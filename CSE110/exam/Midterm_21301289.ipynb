# %%
num=int(input("please enter a number: "))
if num==5:
    print("=== literation 1 ===")
    print("1")
    print("=== literation 2 ===")
    print("X")
    print("XX")
    print("=== literation 3 ===")
    print("123")
    print("123")
    print("123")
    print("=== literation 4 ===")
    print("X")
    print("XX")
    print("XXX")
    print("XXXX")
    print("=== literation 5 ===")
    print("12345")
    print("12345")
    print("12345")
    print("12345")
    print("12345")
elif num==4:
    print("=== literation 1 ===")
    print("1")
    print("=== literation 2 ===")
    print("X")
    print("XX")
    print("=== literation 3 ===")
    print("123")
    print("123")
    print("123")
    print("=== literation 4 ===")
    print("X")
    print("XX")
    print("XXX")
    print("XXXX")
elif num==3:
    print("=== literation 1 ===")
    print("1")
    print("=== literation 2 ===")
    print("X")
    print("XX")
    print("=== literation 3 ===")
    print("123")
    print("123")
    print("123")
elif num==2:
    print("=== literation 1 ===")
    print("1")
    print("=== literation 2 ===")
    print("X")
    print("XX")
else:
    print("=== literation 1 ===")
    print("1")
# Out:
# please enter a number: 5
# === literation 1 ===
# 1
# === literation 2 ===
# X
# XX
# === literation 3 ===
# 123
# 123
# 123
# === literation 4 ===
# X
# XX
# XXX
# XXXX
# === literation 5 ===
# 12345
# 12345
# 12345
# 12345
# 12345

# %%
num=int(input("please enter a number: "))
letter=input("please enter a string: ")
if num%2==0:
    new=(letter[1::2])
    print(new)
    for c in new:
        asci=(ord(new))
        update=asci+1
        print(update)
else:
    new=(letter[1::3])
    print(new)
     for c in new:
        asci=(ord(new))
        update=asci+1
        print(update)
